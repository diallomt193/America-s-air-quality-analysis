# %%
#Import Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# Save path to data set in a variable
data_file = "Resources/data.csv"

# %%
#Read csv file

data_df = pd.read_csv(data_file)
data_df
# Out:
#       CBSA                     Core Based Statistical Area Pollutant  \
# 0    10300                                      Adrian, MI        O3
# 1    10420                                       Akron, OH        O3
# 2    10420                                       Akron, OH       SO2
# 3    10580                     Albany-Schenectady-Troy, NY        O3
# 4    10580                     Albany-Schenectady-Troy, NY       SO2
# 5    10740                                 Albuquerque, NM       NO2
# 6    10740                                 Albuquerque, NM       NO2
# 7    10740                                 Albuquerque, NM        O3
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3
# 10   11020                                     Altoona, PA        O3
# 11   11020                                     Altoona, PA       SO2
# 12   11140                                    Americus, GA        O3
# ...

# %%
#Determine the average of pollutants released from 2010 to 2020 and add it in a new column named "Average"
#This average is calculated across each row
data_df["Average"] = data_df[["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].mean(axis = 1)
data_df
# Out:
#       CBSA                     Core Based Statistical Area Pollutant  \
# 0    10300                                      Adrian, MI        O3
# 1    10420                                       Akron, OH        O3
# 2    10420                                       Akron, OH       SO2
# 3    10580                     Albany-Schenectady-Troy, NY        O3
# 4    10580                     Albany-Schenectady-Troy, NY       SO2
# 5    10740                                 Albuquerque, NM       NO2
# 6    10740                                 Albuquerque, NM       NO2
# 7    10740                                 Albuquerque, NM        O3
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3
# 10   11020                                     Altoona, PA        O3
# 11   11020                                     Altoona, PA       SO2
# 12   11140                                    Americus, GA        O3
# ...

# %%
#Let's also calculate the average of pollutants released from 2011 to 2020 across each column
Average = data_df[["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].mean()
Average
# Out:
# 2011    13.352167
# 2012    13.139665
# 2013    12.617935
# 2014    12.129627
# 2015    10.845612
# 2016     9.628308
# 2017     8.814086
# 2018     8.483573
# 2019     8.139951
# 2020     7.251608
# dtype: float64

# %%
#Do a .loc to get rid of the years that we don't need and create a new dataframe containing only the data we want.
#In this case we are looking at years 2011 through 2020
data_df_copy = data_df.loc[:,["CBSA", "Trend Statistic", "Core Based Statistical Area", "Pollutant", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "Average"]]
data_df_copy
# Out:
#       CBSA  Trend Statistic                     Core Based Statistical Area  \
# 0    10300          4th Max                                      Adrian, MI
# 1    10420          4th Max                                       Akron, OH
# 2    10420  99th Percentile                                       Akron, OH
# 3    10580          4th Max                     Albany-Schenectady-Troy, NY
# 4    10580  99th Percentile                     Albany-Schenectady-Troy, NY
# 5    10740      Annual Mean                                 Albuquerque, NM
# 6    10740  98th Percentile                                 Albuquerque, NM
# 7    10740          4th Max                                 Albuquerque, NM
# 8    10900      Annual Mean               Allentown-Bethlehem-Easton, PA-NJ
# 9    10900          4th Max               Allentown-Bethlehem-Easton, PA-NJ
# 10   11020          4th Max                                     Altoona, PA
# ...

# %%
# Check the names of all the columns and see if there are any rows with missing data
data_df_copy.count()
# Out:
# CBSA                           510
# Trend Statistic                510
# Core Based Statistical Area    510
# Pollutant                      510
# 2011                           510
# 2012                           510
# 2013                           510
# 2014                           510
# 2015                           510
# 2016                           510
# 2017                           510
# 2018                           510
# 2019                           510
# 2020                           510
# Average                        510
# dtype: int64

# %%
# Create a new DataFrame that looks into a specific pollutant SO2
SO2_pollutant_df = data_df_copy.loc[data_df_copy["Pollutant"] == "SO2"]
SO2_pollutant_df.drop_duplicates(subset = "Core Based Statistical Area", keep="first", inplace=True)
SO2_pollutant_df.reset_index(inplace=True)
SO2_pollutant_df
# Out:
# /Users/mariamadiallo/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     index   CBSA  Trend Statistic  \
# 0       2  10420  99th Percentile
# 1       4  10580  99th Percentile
# 2      11  11020  99th Percentile
# 3      17  11780  99th Percentile
# 4      22  12060  99th Percentile
# 5      38  12940  99th Percentile
# 6      42  13140  99th Percentile
# 7      46  13740  99th Percentile
# 8      48  13820  99th Percentile
# 9      52  13900  99th Percentile
# 10     58  14460  99th Percentile
# 11     64  15380  99th Percentile
# 12     75  16700  99th Percentile
# 13     83  16980  99th Percentile
# ...

# %%
#Print the statarea to see the complete list of cities.
statarea = SO2_pollutant_df["Core Based Statistical Area"]
print(statarea)
# Out:
# 0                                         Akron, OH
# 1                       Albany-Schenectady-Troy, NY
# 2                                       Altoona, PA
# 3                                     Ashtabula, OH
# 4                 Atlanta-Sandy Springs-Roswell, GA
# 5                                   Baton Rouge, LA
# 6                          Beaumont-Port Arthur, TX
# 7                                      Billings, MT
# 8                             Birmingham-Hoover, AL
# 9                                      Bismarck, ND
# 10                   Boston-Cambridge-Newton, MA-NH
# 11            Buffalo-Cheektowaga-Niagara Falls, NY
# 12                  Charleston-North Charleston, SC
# 13               Chicago-Naperville-Elgin, IL-IN-WI
# 14                             Cleveland-Elyria, OH
# 15                                      Clinton, IA
# 16                               Corpus Christi, TX
# 17                  Dallas-Fort Worth-Arlington, TX
# ...

# %%
#Pick a city in the list above and plot the data to show the change in SO2 over a 10 year period "2011 - 2020"
#In this case, we picked Akron,OH because it is the first city in the list
#Next, create a dataframe for Akron, OH to observe the change of SO2 pollutant from 2011 to 2020
Akron_data = {'Year': [2011,2012,2013,2014,2015, 2016, 2017, 2018, 2019, 2020],
        'SO2_Rate': [23.0, 22.0, 23.0, 21.0, 14.0, 8.0, 3.0, 6.0, 3.0, 4.0]
       }
Akron_data_df = pd.DataFrame(Akron_data,columns=['Year','SO2_Rate'])
Akron_data_df
# Out:
#    Year  SO2_Rate
# 0  2011      23.0
# 1  2012      22.0
# 2  2013      23.0
# 3  2014      21.0
# 4  2015      14.0
# 5  2016       8.0
# 6  2017       3.0
# 7  2018       6.0
# 8  2019       3.0
# 9  2020       4.0

# %% [markdown]
# This data frame shows a decrease in SO2 release over the years, but the changes will be clearer in a graph (see below).

# %%
plt.plot(Akron_data_df['Year'], Akron_data_df['SO2_Rate'], color='red', marker='o')
plt.title('SO2 Rate Vs Year for Akron, OH', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('SO2 Rate', fontsize=14)
plt.savefig("Images/SO2 Rate Vs Year for Akron, OH.png")
plt.grid(True)
plt.show()

# %% [markdown]
# This graph shows that the release of SO2 has been decreasing for the most part in Akron OH, but there was a slight increase in 2018, then a decrease in 2019 and it started going up a bit again in 2020.

# %%
#let's write a function that can plot a graph for each city in the list showing the change in SO2 from 2011 to 2020
#This function will plot a different graph every time we call it using the index number from the statearea.
def plot_graphs(i):
    Year = [2011,2012,2013,2014,2015, 2016, 2017, 2018, 2019, 2020]
    city_data_df = pd.DataFrame(Akron_data,columns=['Year','SO2_Rate'])
    plt.plot(Year, SO2_pollutant_df.iloc[i, 5:15], color='red', marker='o')
    plt.title('SO2 Rate Vs Year for ' + SO2_pollutant_df.iloc[i, 3], fontsize=14)
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('SO2 Rate', fontsize=14)
    plt.savefig("Images/SO2 Rate Vs Year for " + SO2_pollutant_df.iloc[i, 3]+".png")
    plt.grid(True)
    plt.show()
    
plot_graphs(5)

# %%
#Let's sort the data from highest to lowest average rate of SO2 released between 2011 to 2020 and plot those values to get a cleaner graph
SO2_change = SO2_pollutant_df.sort_values(["Average"], ascending=False)
SO2_change
# Out:
#     index   CBSA  Trend Statistic  \
# 42    326  37740  99th Percentile
# 66    493  48780  99th Percentile
# 62    478  47620  99th Percentile
# 22    143  21780  99th Percentile
# 63    479  47780  99th Percentile
# 30    210  28140  99th Percentile
# 38    303  36540  99th Percentile
# 58    444  45460  99th Percentile
# 14     91  17460  99th Percentile
# 7      46  13740  99th Percentile
# 33    238  30980  99th Percentile
# 27    193  26900  99th Percentile
# 53    402  42340  99th Percentile
# 24    167  24580  99th Percentile
# 64    486  48260  99th Percentile
# 34    243  31140  99th Percentile
# 6      42  13140  99th Percentile
# 45    340  38300  99th Percentile
# 19    112  19500  99th Percentile
# 13     83  16980  99th Percentile
# 28    197  27260  99th Percentile
# 39    311  36980  99th Percentile
# 31    218  29340  99th Percentile
# 15     93  17540  99th Percentile
# 57    442  45300  99th Percentile
# 41    324  37620  99th Percentile
# ...

# %%
#Plot 2 graphs and compare them
#First graph will show the average rate of SO2 released between 2011 and 2020, and the second graph will have the SO2 rates for the 2020
plt.figure(figsize = (40, 10))
plt.plot(SO2_change['Core Based Statistical Area'], SO2_change['Average'], color='red', marker='o', label = '10-year Average')
plt.plot(SO2_change['Core Based Statistical Area'], SO2_change['2020'], color='blue', marker='o', label = '2020')
plt.xticks(rotation = 90)
plt.title('SO2 Rate Vs Year for different cities across the US (Average vs 2020)', fontsize=14)
plt.xlabel('Core Based Statistical Area', fontsize=14)
plt.ylabel('SO2', fontsize=14)
plt.grid(True)
plt.legend()
plt.xlim(-0.5,len(SO2_change['Core Based Statistical Area']))
plt.savefig("Images/SO2 Rate Vs Year for different cities across the US (Average vs 2020).png")
plt.tight_layout()
plt.show()

# %% [markdown]
# According to this graph only 2 cities in the year 2020 had a SO2 rate higher than their average.

# %%
#Now, let's plot the data for all cities to observe the change in SO2 over a five-year period "2016 - 2020"
#In this we decided to show the change for only 5 years because showing the change for 10 will make the graph hard to read.
plt.figure(figsize = (20, 5))
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2016'], color='red', marker='o', label="2016")
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2017'], color='blue', marker='o', label="2017")
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2018'], color='green', marker='o', label="2018")
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2019'], color='magenta', marker='o', label="2019")
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2020'], color='yellow', marker='o', label="2020")
plt.xticks(rotation = 90)
plt.title('SO2 Rate Vs Year for different cities across the US', fontsize=14)
plt.xlabel('Core Based Statistical Area', fontsize=14)
plt.ylabel('SO2', fontsize=14)
plt.savefig("Images/SO2 Rate Vs Year for different cities across the US.png")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# According to the graph, the city of Payson, AZ has the hightest level of SO2 release between the years 2016 and 2019, but then shows a significant decrease in 2020.
