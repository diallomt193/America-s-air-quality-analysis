# %%
#Import Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# Save path to data set in a variable
data_file = "Resources/data.csv"

# %%
#Read csv file

data_df = pd.read_csv(data_file)
data_df
# Out:
#       CBSA                     Core Based Statistical Area Pollutant  \
# 0    10300                                      Adrian, MI        O3
# 1    10420                                       Akron, OH        O3
# 2    10420                                       Akron, OH       SO2
# 3    10580                     Albany-Schenectady-Troy, NY        O3
# 4    10580                     Albany-Schenectady-Troy, NY       SO2
# 5    10740                                 Albuquerque, NM       NO2
# 6    10740                                 Albuquerque, NM       NO2
# 7    10740                                 Albuquerque, NM        O3
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3
# 10   11020                                     Altoona, PA        O3
# 11   11020                                     Altoona, PA       SO2
# 12   11140                                    Americus, GA        O3
# ...

# %%
#Determine the average of pollutant released through the years
#First add an empty column to hold the data
data_df["Average"] = data_df[["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].mean(axis = 1)
data_df
# Out:
#       CBSA                     Core Based Statistical Area Pollutant  \
# 0    10300                                      Adrian, MI        O3
# 1    10420                                       Akron, OH        O3
# 2    10420                                       Akron, OH       SO2
# 3    10580                     Albany-Schenectady-Troy, NY        O3
# 4    10580                     Albany-Schenectady-Troy, NY       SO2
# 5    10740                                 Albuquerque, NM       NO2
# 6    10740                                 Albuquerque, NM       NO2
# 7    10740                                 Albuquerque, NM        O3
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3
# 10   11020                                     Altoona, PA        O3
# 11   11020                                     Altoona, PA       SO2
# 12   11140                                    Americus, GA        O3
# ...

# %%
Average = data_df[["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].mean()
Average
# Out:
# 2010    14.877541
# 2011    13.352167
# 2012    13.139665
# 2013    12.617935
# 2014    12.129627
# 2015    10.845612
# 2016     9.628308
# 2017     8.814086
# 2018     8.483573
# 2019     8.139951
# 2020     7.251608
# dtype: float64

# %%
data_df_copy = data_df.loc[:,["CBSA", "Core Based Statistical Area", "Pollutant", "2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "Average"]]
data_df_copy
# Out:
#       CBSA                     Core Based Statistical Area Pollutant     2010  \
# 0    10300                                      Adrian, MI        O3    0.066
# 1    10420                                       Akron, OH        O3    0.074
# 2    10420                                       Akron, OH       SO2   27.000
# 3    10580                     Albany-Schenectady-Troy, NY        O3    0.072
# 4    10580                     Albany-Schenectady-Troy, NY       SO2   14.000
# 5    10740                                 Albuquerque, NM       NO2   12.000
# 6    10740                                 Albuquerque, NM       NO2   53.000
# 7    10740                                 Albuquerque, NM        O3    0.066
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2   11.000
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3    0.081
# 10   11020                                     Altoona, PA        O3    0.072
# ...

# %%
# Check the names of all the columns and see if there are any rows with missing data
data_df_copy.count()
# Out:
# CBSA                           510
# Core Based Statistical Area    510
# Pollutant                      510
# 2010                           510
# 2011                           510
# 2012                           510
# 2013                           510
# 2014                           510
# 2015                           510
# 2016                           510
# 2017                           510
# 2018                           510
# 2019                           510
# 2020                           510
# Average                        510
# dtype: int64

# %%
# Create a new DataFrame that looks into a specific neighborhood
SO2_pollutant_df = data_df_copy.loc[data_df_copy["Pollutant"] == "SO2"]
SO2_pollutant_df.drop_duplicates(subset = "Core Based Statistical Area", keep="first", inplace=True)
SO2_pollutant_df.reset_index(inplace=True)
SO2_pollutant_df
# Out:
# /Users/mariamadiallo/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#     index   CBSA                    Core Based Statistical Area Pollutant  \
# 0       2  10420                                      Akron, OH       SO2
# 1       4  10580                    Albany-Schenectady-Troy, NY       SO2
# 2      11  11020                                    Altoona, PA       SO2
# 3      17  11780                                  Ashtabula, OH       SO2
# 4      22  12060              Atlanta-Sandy Springs-Roswell, GA       SO2
# 5      38  12940                                Baton Rouge, LA       SO2
# ...

# %%
statareaSO2 = SO2_pollutant_df["Core Based Statistical Area"]
print(statarea)

# %%
Akron_data = {'Year': [2010,2011,2012,2013,2014,2015, 2016, 2017, 2018, 2019, 2020],
        'SO2_Rate': [27.0,24.0,22.0,23.0,21.0,14.0, 8.0, 3.0, 6.0, 3.0, 4.0]
       }
Akron_data_df = pd.DataFrame(Akron_data,columns=['Year','SO2_Rate'])
Akron_data_df

# %%
plt.plot(Akron_data_df['Year'], Akron_data_df['SO2_Rate'], color='red', marker='o')
plt.title('SO2 Rate Vs Year for Akron,OH', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('SO2 Rate', fontsize=14)
plt.grid(True)
plt.show()

# %%
# Filter the DataFrame down only to those columns to chart
area_and_year_df = SO2_pollutant_df[["Core Based Statistical Area","2010"]]
# # Set the index to be "State" so they will be used as labels
# area_and_years = new_data_df.set_index("Core Based Statistical Area")

area_and_year_df
# Out:
#                       Core Based Statistical Area   2010
# 0                                       Akron, OH   27.0
# 1                     Albany-Schenectady-Troy, NY   14.0
# 2                                     Altoona, PA   36.0
# 3                                   Ashtabula, OH   20.0
# 4               Atlanta-Sandy Springs-Roswell, GA   33.0
# 5                                 Baton Rouge, LA   64.0
# 6                        Beaumont-Port Arthur, TX   75.0
# 7                                    Billings, MT   91.0
# 8                           Birmingham-Hoover, AL   33.0
# 9                                    Bismarck, ND   59.0
# 10                 Boston-Cambridge-Newton, MA-NH   20.0
# 11          Buffalo-Cheektowaga-Niagara Falls, NY   15.0
# 12                Charleston-North Charleston, SC   17.0
# 13             Chicago-Naperville-Elgin, IL-IN-WI   57.0
# 14                           Cleveland-Elyria, OH   49.0
# ...

# %%
#let's plot the data
plt.figure(figsize = (20, 5))
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2010'], color='red', marker='o', label="2010")
plt.plot(SO2_pollutant_df['Core Based Statistical Area'], SO2_pollutant_df['2011'], color='blue', marker='o', label="2011")
plt.xticks(rotation = 90)
plt.title('SO2 Rate Vs Year for different cities across the US', fontsize=14)
plt.xlabel('Core Based Statistical Area', fontsize=14)
plt.ylabel('SO2', fontsize=14)
plt.grid(True)
plt.legend()
plt.show()

# %%
x = input("choose a city")
x
# Out:
# choose a cityAkron, OH
# 'Akron, OH'
