# %%
#Import Dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# Save path to data set in a variable
data_file = "Resources/data.csv"

# %%
#Read csv file

data_df = pd.read_csv(data_file)
data_df
# Out:
#       CBSA                     Core Based Statistical Area Pollutant  \
# 0    10300                                      Adrian, MI        O3
# 1    10420                                       Akron, OH        O3
# 2    10420                                       Akron, OH       SO2
# 3    10580                     Albany-Schenectady-Troy, NY        O3
# 4    10580                     Albany-Schenectady-Troy, NY       SO2
# 5    10740                                 Albuquerque, NM       NO2
# 6    10740                                 Albuquerque, NM       NO2
# 7    10740                                 Albuquerque, NM        O3
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3
# 10   11020                                     Altoona, PA        O3
# 11   11020                                     Altoona, PA       SO2
# 12   11140                                    Americus, GA        O3
# ...

# %%
#Determine the average of pollutant released from 2011 to 2020 and add it in a new column named "Average"
#This average is calculated across each row
data_df["Average"] = data_df[["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].mean(axis = 1)
data_df
# Out:
#       CBSA                     Core Based Statistical Area Pollutant  \
# 0    10300                                      Adrian, MI        O3
# 1    10420                                       Akron, OH        O3
# 2    10420                                       Akron, OH       SO2
# 3    10580                     Albany-Schenectady-Troy, NY        O3
# 4    10580                     Albany-Schenectady-Troy, NY       SO2
# 5    10740                                 Albuquerque, NM       NO2
# 6    10740                                 Albuquerque, NM       NO2
# 7    10740                                 Albuquerque, NM        O3
# 8    10900               Allentown-Bethlehem-Easton, PA-NJ       NO2
# 9    10900               Allentown-Bethlehem-Easton, PA-NJ        O3
# 10   11020                                     Altoona, PA        O3
# 11   11020                                     Altoona, PA       SO2
# 12   11140                                    Americus, GA        O3
# ...

# %%
#Let's also calculate the average of pollutant released from 2011 to 2020 across each column
Average = data_df[["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020"]].mean()
Average
# Out:
# 2011    13.352167
# 2012    13.139665
# 2013    12.617935
# 2014    12.129627
# 2015    10.845612
# 2016     9.628308
# 2017     8.814086
# 2018     8.483573
# 2019     8.139951
# 2020     7.251608
# dtype: float64

# %%
#Do a .loc to get rid of the years that we don't need and create a new dataframe containing only the data we want.
#In this case we are looking at years 2011 through 2020
data_df_copy = data_df.loc[:,["CBSA", "Trend Statistic", "Core Based Statistical Area", "Pollutant", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018", "2019", "2020", "Average"]]
data_df_copy
# Out:
#       CBSA  Trend Statistic                     Core Based Statistical Area  \
# 0    10300          4th Max                                      Adrian, MI
# 1    10420          4th Max                                       Akron, OH
# 2    10420  99th Percentile                                       Akron, OH
# 3    10580          4th Max                     Albany-Schenectady-Troy, NY
# 4    10580  99th Percentile                     Albany-Schenectady-Troy, NY
# 5    10740      Annual Mean                                 Albuquerque, NM
# 6    10740  98th Percentile                                 Albuquerque, NM
# 7    10740          4th Max                                 Albuquerque, NM
# 8    10900      Annual Mean               Allentown-Bethlehem-Easton, PA-NJ
# 9    10900          4th Max               Allentown-Bethlehem-Easton, PA-NJ
# 10   11020          4th Max                                     Altoona, PA
# ...

# %%
# Check the names of all the columns and see if there are any rows with missing data
data_df_copy.count()
# Out:
# CBSA                           510
# Trend Statistic                510
# Core Based Statistical Area    510
# Pollutant                      510
# 2011                           510
# 2012                           510
# 2013                           510
# 2014                           510
# 2015                           510
# 2016                           510
# 2017                           510
# 2018                           510
# 2019                           510
# 2020                           510
# Average                        510
# dtype: int64

# %%
# Create a new DataFrame that looks into a specific pollutant O3
O3_pollutant_df = data_df_copy.loc[data_df_copy["Pollutant"] == "O3"]
O3_pollutant_df.drop_duplicates(subset = "Core Based Statistical Area", keep="first", inplace=True)
O3_pollutant_df.reset_index(inplace=True)
O3_pollutant_df
# Out:
# /Users/mariamadiallo/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#      index   CBSA Trend Statistic  \
# 0        0  10300         4th Max
# 1        1  10420         4th Max
# 2        3  10580         4th Max
# 3        7  10740         4th Max
# 4        9  10900         4th Max
# 5       10  11020         4th Max
# 6       12  11140         4th Max
# 7       13  11460         4th Max
# 8       14  11540         4th Max
# 9       15  11700         4th Max
# 10      16  11780         4th Max
# 11      18  12020         4th Max
# 12      21  12060         4th Max
# 13      23  12260         4th Max
# ...

# %%
#Print the statarea to see the complete list of cities.
statarea = O3_pollutant_df["Core Based Statistical Area"]
print(statarea)
# Out:
# 0                                          Adrian, MI
# 1                                           Akron, OH
# 2                         Albany-Schenectady-Troy, NY
# 3                                     Albuquerque, NM
# 4                   Allentown-Bethlehem-Easton, PA-NJ
# 5                                         Altoona, PA
# 6                                        Americus, GA
# 7                                       Ann Arbor, MI
# 8                                        Appleton, WI
# 9                                       Asheville, NC
# 10                                      Ashtabula, OH
# 11                           Athens-Clarke County, GA
# 12                  Atlanta-Sandy Springs-Roswell, GA
# 13                     Augusta-Richmond County, GA-SC
# 14                             Augusta-Waterville, ME
# 15                              Austin-Round Rock, TX
# 16                                    Bakersfield, CA
# ...

# %%
#Pick a city in the list above and plot the data to show the change in O3 over a 10 year period "2011 - 2020"
#In this case, we picked Adrian,MI because it is the first city in the list
#Next, create a dataframe for Adrian,MI to observe the change of O3 pollutant from 2011 to 2020
Adrian_data = {'Year': [2011,2012,2013,2014,2015, 2016, 2017, 2018, 2019, 2020],
        'O3_Rate': [0.076, 0.087, 0.064, 0.068, 0.065, 0.069, 0.066, 0.071, 0.059, 0.067]
       }
Adrian_data_df = pd.DataFrame(Adrian_data,columns=['Year','O3_Rate'])
Adrian_data_df
# Out:
#    Year  O3_Rate
# 0  2011    0.076
# 1  2012    0.087
# 2  2013    0.064
# 3  2014    0.068
# 4  2015    0.065
# 5  2016    0.069
# 6  2017    0.066
# 7  2018    0.071
# 8  2019    0.059
# 9  2020    0.067

# %%
plt.plot(Adrian_data_df['Year'], Adrian_data_df['O3_Rate'], color='red', marker='o')
plt.title('O3 Rate Vs Year for Adrian,MI', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('O3 Rate', fontsize=14)
plt.savefig("Images/O3 Rate Vs Year for Adrian,MI.png")
plt.grid(True)
plt.show()

# %% [markdown]
# This graph shows a decrease in O3 release between the years 2012 and 2013, but then the rate seems to jump up and down over the next years.

# %%
#let's write a function that can plot a graph for each city in the list showing the change in O3 from 2011 to 2020
#This function will plot a different graph every time we call it using the index number from the statearea.
def plot_graphs(i):
    Year = [2011,2012,2013,2014,2015, 2016, 2017, 2018, 2019, 2020]
    city_data_df = pd.DataFrame(Adrian_data,columns=['Year','O3_Rate'])
    plt.plot(Year, O3_pollutant_df.iloc[i, 5:15], color='red', marker='o')
    plt.title('O3 Rate Vs Year for ' + O3_pollutant_df.iloc[i, 3], fontsize=14)
    plt.xlabel('Year', fontsize=14)
    plt.ylabel('O3 Rate', fontsize=14)
    plt.savefig("Images/O3 Rate Vs Year for " + O3_pollutant_df.iloc[i, 3]+".png")
    plt.grid(True)
    plt.show()

plot_graphs(11)

# %%
#Let's sort the data from highest to lowest average rate of O3 released between 2011 to 2020 and plot those values to get a cleaner graph
O3_change = O3_pollutant_df.sort_values(["Average"], ascending=False)
O3_change
# Out:
#      index   CBSA Trend Statistic  \
# 228    476  47300         4th Max
# 16      28  12540         4th Max
# 95     172  25260         4th Max
# 218    449  46020         4th Max
# 145    275  33700         4th Max
# 33      60  14860         4th Max
# 138    259  32900         4th Max
# 198    412  43100         4th Max
# 129    247  31460         4th Max
# 100    179  26090         4th Max
# 151    282  34740         4th Max
# 202    416  43760         4th Max
# 64     115  19740         4th Max
# 176    347  39780         4th Max
# 156    294  35660         4th Max
# 47      84  17020         4th Max
# 169    325  37740         4th Max
# 56     103  19100         4th Max
# 131    249  31820         4th Max
# 98     177  25540         4th Max
# 17      31  12580         4th Max
# 217    448  45940         4th Max
# 40      70  16100         4th Max
# 89     165  24540         4th Max
# 186    382  41700         4th Max
# 141    265  33140         4th Max
# ...

# %%
#Plot 2 graphs and compare them
#First graph will show the average rate of NO2 released between 2011 and 2020, and the second graph will have the NO2 rates for the 2020
plt.figure(figsize = (40, 10))
plt.plot(O3_change['Core Based Statistical Area'], O3_change['Average'], color='red', marker='o', label='10-year Average')
plt.plot(O3_change['Core Based Statistical Area'], O3_change['2020'], color='blue', marker='o', label = '2020')
plt.xticks(rotation = 90)
plt.title('O3 Rate Vs Year for different cities across the US (Average vs 2020)', fontsize=14)
plt.xlabel('Core Based Statistical Area', fontsize=14)
plt.ylabel('O3', fontsize=14)
plt.grid(True)
plt.legend()
plt.xlim(-0.5,len(O3_change['Core Based Statistical Area']))
plt.savefig("Images/O3 Rate Vs Year for different cities across the US (Average vs 2020).png")
plt.tight_layout()
plt.show()

# %% [markdown]
# According to this graph many cities in the year 2020 had a O3 rate higher than their average.

# %%
#Now, let's plot the data for all cities to observe the change in O3 over a five-year period "2016 - 2020"
#In this we decided to show the change for only 5 years because showing the change for 10 will make the graph hard to read.
plt.figure(figsize = (30, 20))
plt.plot(O3_pollutant_df['Core Based Statistical Area'], O3_pollutant_df['2016'], color='red', marker='o', label="2016")
plt.plot(O3_pollutant_df['Core Based Statistical Area'], O3_pollutant_df['2017'], color='blue', marker='o', label="2017")
plt.plot(O3_pollutant_df['Core Based Statistical Area'], O3_pollutant_df['2018'], color='green', marker='o', label="2018")
plt.plot(O3_pollutant_df['Core Based Statistical Area'], O3_pollutant_df['2019'], color='magenta', marker='o', label="2019")
plt.plot(O3_pollutant_df['Core Based Statistical Area'], O3_pollutant_df['2020'], color='yellow', marker='o', label="2020")
plt.xticks(rotation = 90)
plt.title('O3 Rate Vs Year for different cities across the US', fontsize=14)
plt.xlabel('Core Based Statistical Area', fontsize=14)
plt.ylabel('O3', fontsize=14)
plt.savefig("Images/O3 Rate Vs Year for different cities across the US.png")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Due to the number of cities, it is impossible to tell which city has the highest number of O3 released between 2016 and 2020.
